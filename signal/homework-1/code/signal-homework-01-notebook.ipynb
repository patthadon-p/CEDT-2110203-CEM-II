# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
def unit_signal(t):
    return 1.0 if t >= 0 else 0.0

unit_signal_vectorize = np.vectorize(unit_signal)

# %%
def ramp_signal(t):
    return t * unit_signal(t)

ramp_signal_vectorize = np.vectorize(ramp_signal)

# %% [markdown]
# ## Problem 1
# Sketch the following signals

# %%
# Problem 1.1.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-10, 10, 0.01)
x = np.sin(np.pi/4 * t + np.pi/9)

plt.title("Problem 1.1")
plt.plot(t, x, label=r"$x(t) = \sin(\frac{\pi}{4}t + 20^\circ)$")
plt.legend(loc="upper right")
plt.grid(True)

plt.savefig("../images/problem_1_1.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 1.2.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-10, 10, 0.01)
x = np.piecewise(t, [t < -2, (t >= -2) & (t < 2), t >= 2], [lambda t: t + 2, 0, lambda t: t - 2])

plt.title("Problem 1.2")
plt.plot(t, x, label=r"$x(t) = t+2, t < -2 \;;\; 0, -2 \leq t < 2 \;;\; t-2, t \geq 2$")
plt.legend(loc="upper right")
plt.grid(True)

plt.savefig("../images/problem_1_2.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 1.3.

def x3(t):
    if t >= 1:
        return x3(t - 1)
    if t < 0:
        return x3(t + 1)
    return 2 * (np.e ** (-t))

fig = plt.figure(figsize=(10, 4))

t = np.arange(-10, 10, 0.01)
x3_vectorize = np.vectorize(x3)
x = x3_vectorize(t)

plt.title("Problem 1.3")
plt.plot(t, x, label=r"$x(t) = 2e^{-t}, 0 \leq t < 1 \text{ and } x(t + 1) = x(t), \forall t$")
plt.legend(loc="upper right")
plt.grid(True)

plt.savefig("../images/problem_1_3.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 1.4.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-6, 6, 0.01)

u1 = unit_signal_vectorize(t)
u2 = unit_signal_vectorize(t - 1)
u3 = unit_signal_vectorize(t - 2)

x = u1 + 5 * u2 - 2 * u3

plt.title("Problem 1.4")
plt.plot(t, x, label=r"$u(t) + 5u(t-1) - 2u(t-2)$")
plt.legend(loc="upper right")
plt.grid(True)

plt.savefig("../images/problem_1_4.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 1.5.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-2, 4, 0.01)

r1 = ramp_signal_vectorize(t)
r2 = ramp_signal_vectorize(t - 1)
u1 = unit_signal_vectorize(t - 2)

x = r1 - r2 - u1

plt.title("Problem 1.5")
plt.plot(t, x, label=r"$r(t) - r(t-1) - u(t-2)$")
plt.legend(loc="upper right")
plt.grid(True)

plt.savefig("../images/problem_1_5.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Problem 2
# Determine whether each of following signals is periodic, and if so, find its period.
#
# 1. $x(t) = \sin \left( \frac{\pi}{3}t \right) + \cos \left( \frac{8\pi}{3}t \right)$
#
# 2. $x(t) = \exp \left  (j\frac{7\pi}{6}t \right) +  \exp \left( j\frac{5\pi}{6}t \right) $
#
# 3. $x(t) = \exp \left( j\frac{7\pi}{6}t \right) +  \exp \left(\frac{5\pi}{6}t \right) $

# %%
# 2.1

fig = plt.figure(figsize=(10, 4))

t = np.arange(-12, 12, 0.01)

x1 = np.sin(np.pi/3 * t)
x2 = np.cos(8*np.pi/3 * t)

x = np.sin(np.pi/3 * t)

plt.title("Problem 2.1")
plt.plot(t, x1 + x2, label=r"$x(t) = \sin\left(\frac{\pi}{3}t\right) + \cos\left(\frac{8\pi}{3}t\right)$")
plt.plot(t, x, label="sinusoidal signal with period 6")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_2_1.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 2.2

fig = plt.figure(figsize=(10, 4))

t = np.arange(-24, 24, 0.01)

x1 = np.exp(1j * 7*np.pi/6 * t)
x2 = np.exp(1j * 5*np.pi/6 * t)

x = np.exp(1j * np.pi/6 * t)

plt.title("Problem 2.2")
plt.plot(t, x1 + x2, label=r"$r(t) = \exp(j\,\frac{7\pi}{6}t) + \exp(j\,\frac{5\pi}{6}t)$")
plt.plot(t, x, label="sinusoidal signal with period 12")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_2_2.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# /home/nodahttap/study/cedt-2-1/2110203-cem-2/CEDT-2110203-CEM-II/.venv/lib/python3.10/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/nodahttap/study/cedt-2-1/2110203-cem-2/CEDT-2110203-CEM-II/.venv/lib/python3.10/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# 2.3

fig = plt.figure(figsize=(10, 4))

t = np.arange(-5, 5, 0.01)

x1 = np.exp(1j * 7*np.pi/6 * t)
x2 = np.exp(5*np.pi/6 * t)

plt.title("Problem 2.3")
plt.plot(t, x1 + x2, label=r"$r(t) = \exp(j\,\frac{7\pi}{6}t) + \exp(\frac{5\pi}{6}t)$")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_2_3.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Problem 3
# Determine whether the following signals are power or energy signals or neither. Justify your answers
#
# 1. $x(t) = A\sin( t ), -\infty < t < \infty$
# 2. $x(t) = A(u(t-a) - u(t+a)), \, a>0 $
# 4. $x(t) = \exp(-at)u(t), \,  a>0 $
# 7. $x(t) = A\exp(bt)u(t), \, b>0$

# %%
# 3.1

fig = plt.figure(figsize=(10, 4))

t = np.arange(-10, 10, 0.01)
x = np.sin(t)

plt.title("Problem 3.1")
plt.plot(t, x, label=r"$x(t) = A\sin(t) \;; A = 1$")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_3_1.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 3.2

fig = plt.figure(figsize=(10, 4))

t = np.arange(-4, 4, 0.01)
x = unit_signal_vectorize(t - 1) - unit_signal_vectorize(t + 1)

plt.title("Problem 3.2")
plt.plot(t, x, label=r"$x(t) = A\left(u(t-a) - u(t+a)\right) \;; A = 1, a = 1$")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_3_2.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 3.3

fig = plt.figure(figsize=(10, 4))

t = np.arange(-8, 8, 0.01)
x = np.exp(-t) * unit_signal_vectorize(t)

plt.title("Problem 3.3")
plt.plot(t, x, label=r"$x(t) = \exp(-at)u(t) \;; a = 1$")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_3_3.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 3.4

fig = plt.figure(figsize=(10, 4))

t = np.arange(-4, 6, 0.01)
x = np.exp(t) * unit_signal_vectorize(t)

plt.title("Problem 3.4")
plt.plot(t, x, label=r"$x(t) = A\exp(bt) \;; A = 1, b = 1$")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_3_4.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Problem 4
# For the discrete time signal x[n] shown in Figure below, sketch each of the following
#
# 1. $x[2-n] $
# 2. $x[3n-4] $
# 3. $x\left[ \frac{2}{3}n+1 \right]  $
# 4. $x\left[-\frac{n+8}{4} \right] $
# 5. $x[n^3] $
# 8. $x[2-n] +x[3n-4] $

# %%
# x[n]

fig = plt.figure(figsize=(6, 4))

t = np.arange(-2,4)
x_t = np.array([-3,1,2,-2,3,-1])

plt.stem(t, x_t)
plt.title(r"$x[n]$")

plt.savefig("../images/problem_4_xn.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
def transform_signal(x, n, f):
    """Return x[f(n)] for any discrete-time signal x[n]."""
    f_n = f(n)
    f_n_int = f_n[np.floor(f_n) == f_n]
    
    x_new = np.zeros(f_n_int.shape[0], dtype=float)
    
    idx = 0
    for i, val in enumerate(f_n):
        if int(val) == val:
            x_new[idx] = x[i]
            idx += 1
    
    return x_new, f_n_int

# %%
# 4.1.

fig = plt.figure(figsize=(6, 4))

t = np.arange(-2, 4)
x_t = np.array([-3, 1, 2, -2, 3, -1])

x_t, t = transform_signal(x_t, t, lambda n: 2 - n)

plt.stem(t, x_t)
plt.title(r"$x[2 - n]$")

plt.savefig("../images/problem_4_1.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 4.2.

fig = plt.figure(figsize=(6, 4))

t = np.arange(-2, 4)
x_t = np.array([-3, 1, 2, -2, 3, -1])

x_t, t = transform_signal(x_t, t, lambda x: (x + 4) / 3)

plt.stem(t, x_t)
plt.title(r"$x[3n - 4]$")

plt.savefig("../images/problem_4_2.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 4.3.

fig = plt.figure(figsize=(6, 4))

t = np.arange(-2, 4)
x_t = np.array([-3, 1, 2, -2, 3, -1])

x_t, t = transform_signal(x_t, t, lambda x: (x - 1) * 3 / 2)

plt.stem(t, x_t)
plt.title(r"$x[\frac{2}{3}n + 1]$")

plt.savefig("../images/problem_4_3.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 4.4.

fig = plt.figure(figsize=(6, 4))

t = np.arange(-2, 4)
x_t = np.array([-3, 1, 2, -2, 3, -1])

x_t, t = transform_signal(x_t, t, lambda x: (-4 * x) - 8)

plt.stem(t, x_t)
plt.title(r"$x[-\frac{n + 8}{4}]$")

plt.savefig("../images/problem_4_4.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 4.5.

fig = plt.figure(figsize=(6, 4))

t = np.arange(-2, 4)
x_t = np.array([-3, 1, 2, -2, 3, -1])

x_t, t = transform_signal(x_t, t, lambda x: np.cbrt(x))

plt.stem(t, x_t)
plt.title(r"$x[n^3]$")

plt.savefig("../images/problem_4_5.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
def add_discrete_signals(x1, t1, x2, t2):
    """Return x1[n] + x2[n] for any discrete-time signals x1[n] and x2[n]."""
    t = np.union1d(t1, t2)
    x = np.zeros(t.shape[0], dtype=float)
    
    for i, val in enumerate(t):
        if val in t1:
            x[i] += x1[np.where(t1 == val)[0][0]]
        if val in t2:
            x[i] += x2[np.where(t2 == val)[0][0]]
    
    return x, t

# %%
# 4.6.

fig = plt.figure(figsize=(6, 4))

t = np.arange(-2, 4)
x_t = np.array([-3, 1, 2, -2, 3, -1])

x_t_1, t_1 = transform_signal(x_t, t, lambda x: 2 - x)
x_t_2, t_2 = transform_signal(x_t, t, lambda x: (x + 4) / 3)

x_t, t = add_discrete_signals(x_t_1, t_1, x_t_2, t_2)

plt.stem(t, x_t)
plt.title(r"$x[2-n] + x[3n-4]$")

plt.savefig("../images/problem_4_6.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Problem 5
# Determine whether each of following signals is periodic, and if so, find its period.
#
# 1. $x[n] = \sin \left( \frac{\pi n}{4} + \frac{\pi}{8}\right)$
#
# 2. $x[n] = \sin \left( \frac{3\pi n}{4}\right) + \sin\left( \frac{\pi}{3}n\right)$
#
# 3. $x[n] = \sin \left( \frac{3\pi n}{4}\right)\sin\left( \frac{\pi}{3}n\right)$
#
# 4. $x[n] = \exp \left( \frac{6\pi}{5}n \right)$
#
# 5. $x[n] = \exp \left( j\frac{5\pi}{6}n \right)$
#
# 6. $x[n] =  \sum_{m=-\infty}^{\infty} \left[ \delta[n-2m] + 2\delta[n-3m] \right]$
#
# <!-- 1.
# $x[n] = \sin \left( \frac{3\pi n}{4}\right) + \cos \left( \frac{\pi}{3} n \right)$ -->

# %%
# 5.1.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-24, 25, 1)
x = np.sin(np.pi/4 * t + np.pi/8)

tc = np.arange(-24, 24, 0.01)
xc = np.sin(np.pi/4 * tc + np.pi/8)

plt.title("Problem 5.1")
plt.stem(t, x, label=r"$x[n] = \sin(\frac{\pi}{4} n + \frac{\pi}{8})$")
plt.plot(tc, xc, "r", alpha=0.8, label="continuous sinusoidal signal with period 8")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_5_1.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 5.2.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-72, 73, 1)
x = np.sin(3 * np.pi/4 * t) + np.sin(np.pi/3 * t)

tc = np.arange(-72, 72, 0.01)
xc = np.sin(np.pi/12 * tc)

plt.title("Problem 5.2")
plt.stem(t, x, label=r"$x[n] = \sin(\frac{3\pi}{4}n) + \sin(\frac{\pi}{3}n)$")
plt.plot(tc, xc, "r", alpha=0.8, label="continuous sinusoidal signal with period 24")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_5_2.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 5.3.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-72, 73, 1)
x = np.sin(3 * np.pi/4 * t) * np.sin(np.pi/3 * t)

tc = np.arange(-72, 72, 0.01)
xc = np.sin(np.pi/12 * tc)

plt.title("Problem 5.3")
plt.stem(t, x, label=r"$x[n] = \sin(\frac{3\pi}{4}n) \sin(\frac{\pi}{3}n)$")
plt.plot(tc, xc, "r", alpha=0.8, label="continuous sinusoidal signal with period 24")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_5_3.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 5.4.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-2, 3, 1)
x = np.exp(6 * np.pi/5 * t)

tc = np.arange(-2, 2, 0.01)
xc = np.exp(6 * np.pi/5 * tc)

plt.title("Problem 5.4")
plt.stem(t, x, label=r"$x[n] = \exp(\frac{6\pi}{5}n)$")
plt.plot(tc, xc, "r", alpha=0.8, label="continuous exponential signal")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_5_4.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 5.5.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-36, 37, 1)
x = np.exp(1j * 5 * np.pi/6 * t)

tc = np.arange(-36, 36, 0.01)
xc = np.exp(1j * np.pi/6 * tc)

plt.title("Problem 5.5")
plt.stem(t, x, label=r"$x[n] = \exp(j\,\frac{5\pi}{6}n)$")
plt.plot(tc, xc, "r", alpha=0.8, label="continuous sinusoidal signal with period 12")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_5_5.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# /home/nodahttap/study/cedt-2-1/2110203-cem-2/CEDT-2110203-CEM-II/.venv/lib/python3.10/site-packages/numpy/ma/core.py:3463: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data[indx] = dval

# %%
# 5.6.

fig = plt.figure(figsize=(10, 4))

t = np.arange(-12, 13, 1)
x1 = np.isin(np.mod(t, 2), [0]).astype(float) # delta[n-2k]
x2 = np.isin(np.mod(t, 3), [0]).astype(float) # delta[n-3k]

x = x1 + 2 * x2

tc = np.arange(-12, 12, 0.01)
xc = np.exp(1j * np.pi/3 * tc)

plt.title("Problem 5.6")
plt.stem(t, x, label=r"$x[n] = \delta[n-2k] + 2\delta[n-3k]$")
plt.plot(tc, xc, "r", alpha=0.8, label="continuous sinusoidal signal with period 6")
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_5_6.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
#  ## Problem 6
#
#  [python] Signal transformations :
#  Study the sawtooth function in the figure below. Apply reflection, scaling, shifting operations to the signal and plot the transformed signals compared with the original sawtooth signal.

# %%
import numpy as np
from scipy import signal

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(5, 4))

t = np.linspace(-1, 1, 500)
sawtooth = signal.sawtooth(2 * np.pi * 5 * t)

plt.title("Sawtooth Signal")
plt.plot(t, sawtooth)

plt.savefig("../images/problem_6_sawtooth.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 6.1.

fig = plt.figure(figsize=(10, 4))

t = np.linspace(-1, 1, 500)
sawtooth = signal.sawtooth(2 * np.pi * 5 * t)

# scaling factor = 3 and 1/3
## TODO : writing code for time scaling

t1 = t * 3
sawtooth1 = signal.sawtooth(2 * np.pi * 5 * t1)

t2 = t * (1/3)
sawtooth2 = signal.sawtooth(2 * np.pi * 5 * t2)

plt.title("Time Scaling: Sawtooth Signal")
plt.plot(t, sawtooth, label=r"Original: sawtooth$(t)$", alpha=1)
plt.plot(t, sawtooth1, label=r"Compressed: sawtooth$(3t)$", linestyle="--", alpha=0.8)
plt.plot(t, sawtooth2, label=r"Expanded: sawtooth$(t/3)$", linestyle="--", alpha=0.8)
plt.legend(loc="upper right")

plt.savefig("../images/problem_6_1.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 6.2.

fig = plt.figure(figsize=(10, 4))

t = np.linspace(-1, 1, 500)
sawtooth = signal.sawtooth(2 * np.pi * 5 * t)

## TODO : writing code for time shifting
# shifting t to the left and right 0.05 units

t1 = t + 0.05
sawtooth1 = signal.sawtooth(2 * np.pi * 5 * t1)

t2 = t - 0.05
sawtooth2 = signal.sawtooth(2 * np.pi * 5 * t2)

plt.title("Time Shifting: Sawtooth Signal")
plt.plot(t, sawtooth, label=r"Original: sawtooth$(t)$", alpha=1)
plt.plot(t, sawtooth1, label=r"Left Shift: sawtooth$(t + 0.05)$", linestyle="--", alpha=0.8)
plt.plot(t, sawtooth2, label=r"Right Shift: sawtooth$(t - 0.05)$", linestyle="--", alpha=0.8)
plt.legend(loc="upper right")

plt.savefig("../images/problem_6_2.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
# 6.3.

fig = plt.figure(figsize=(10, 4))

t = np.linspace(-1, 1, 500)
sawtooth = signal.sawtooth(2 * np.pi * 5 * t)

## TODO : writing code for time Reflection

t1 = t
sawtooth1 = signal.sawtooth(2 * np.pi * 5 * (-1 * t))

plt.title("Time Reflection: Sawtooth Signal")
plt.plot(t, sawtooth, label=r"Original: sawtooth$(t)$", alpha=1)
plt.plot(t, sawtooth1, label=r"Reflected: sawtooth$(-t)$", linestyle="--", alpha=0.8)
plt.legend(loc="upper right")

plt.savefig("../images/problem_6_3.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Problem 7
# Elementary signals: study  the ramp signal plotted in the example below.
#
# TODO : plot these signals
#
# 1.   Unit step function
# 2.   Unit impulse function

# %%
fig = plt.figure(figsize=(10, 4))

t = np.linspace(-1, 1, 500)

## TODO : writing code for plotting unit step function

x = unit_signal_vectorize(t)

plt.title("Unit step function")
plt.plot(t, x, label=r"$u(t)$", alpha=1)
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_7_1.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 4))

t = np.linspace(-1, 1, 500)

## TODO : writing code for plotting unit impulse function

x = np.zeros(t.shape[0])
x[t == 0] = 1

arrow = plt.arrow(0, 0, 0, 1, head_width=0.02, head_length=0.05, fc="blue", ec="blue")
origin = plt.plot(0, 0, color="blue", marker = "o", markerfacecolor="white", markersize=5)

plt.title("Unit impulse function")
plt.plot(t, x, label=r"$\delta(t)$", alpha=1)
plt.grid(True)
plt.legend(loc="upper right")

plt.savefig("../images/problem_7_2.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Problem 8
# Express the signal that shown in Figure below using Unit-ramp functions

# %% [markdown]
# <a href="https://ibb.co/pXt8t2Y"><img src="https://i.ibb.co/DKxyx40/Screen-Shot-2564-08-11-at-15-16-52.png" alt="Screen-Shot-2564-08-11-at-15-16-52" border="0"></a>

# %%
import requests

url = "https://i.ibb.co/DKxyx40/Screen-Shot-2564-08-11-at-15-16-52.png"

r = requests.get(url)
with open("../images/problem_8_reference.png", "wb") as f:
    f.write(r.content)

print("Image saved as problem_8_reference.png")
# Out:
# Image saved as problem_8_reference.png

# %%
fig = plt.figure(figsize=(8, 4))

t = np.linspace(-2, 5, 500)

x = np.zeros(t.shape[0])

x += ramp_signal_vectorize(t + 1) * (-1)            # -r(t+1)
x += ramp_signal_vectorize(t - 0) * (1 + 2.5)       # 3.5r(t)
x += ramp_signal_vectorize(t - 1) * (-2.5 + -0.5)   # -3r(t-1)
x += ramp_signal_vectorize(t - 2) * (0.5 + -1)      # -0.5r(t-2)
x += ramp_signal_vectorize(t - 3) * (1)             # r(t-3)

plt.title("Problem 8, expressed using Unit-ramp functions")
plt.plot(t, x, label=r"$-r(t+1)+3.5r(t)-3r(t-1)-0.5r(t-2)+r(t-3)$")
plt.legend(loc="lower right")
plt.grid(True)

plt.savefig("../images/problem_8.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Problem 9
#
# Evaluate the following integrals
#
# 1. $\int_{-\infty}^{\infty} \left( \frac{2}{3}t-\frac{3}{2} \right) \delta(t-1) \,dt$
#
# 1. $\int_{-\infty}^{\infty} (t-1) \delta \left(\frac{2}{3}t- \frac{3}{2} \right) \,dt$
#
# 1. $\int_{-3}^{-2} \left[ e^{(-t+1)} + \sin \left( \frac{2\pi t}{3} \right) \right] \delta \left(t- \frac{3}{2} \right) \,dt$
#
# 1. $\int_{-3}^{2} \left[ e^{(-t+1)} + \sin \left( \frac{2\pi t}{3} \right) \right] \delta \left(t- \frac{3}{2} \right) \,dt$
